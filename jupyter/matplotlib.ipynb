# %% [markdown]
# # Samples for matplotlib
#
# [Installing Jupyter Notebook in Mac M1 2023](https://medium.com/@sandupa.egodage/installing-jupyter-notebook-in-mac-m1-2023-8eb158af56b0#id_token=eyJhbGciOiJSUzI1NiIsImtpZCI6ImMzYWJlNDEzYjIyNjhhZTk3NjQ1OGM4MmMxNTE3OTU0N2U5NzUyN2UiLCJ0eXAiOiJKV1QifQ.....rqwCS1AvIKI168FoeaLSNKyyU7Y7SyiJ_G1CwJcX_VJ0hmrn5Q9c3avnr43D1nZk1dwQ7Uip9x3kgq-OPzwK-Yo2f9FAzzVQb2sjQiDopNhPDxrZghcVOfPdvDpuy3PNdsCBxsXp_y7TKT7kTovsC-TFfxx-aOh_Y54r409kjqYmZu953YDpApXf4LaHBT6uQXnnmGd8zEvxYLdXkreBSGACQBsHp20IoVM5kzZttdxT8nhwI2tKLflr2FAeYMs29dw00XoN6lMB8kCYQ5eub8u17IAaCTbhZQ2rwAOdw6n6GZsPG-BNYm1EN3LOyjwJWr3JhBW4VdhpXkXlo3jqlQ)

# %%
import matplotlib.pyplot as plt
import numpy as np

# 数据
data = [np.random.normal(0, std, 100) for std in range(1, 4)]

# 绘制箱线图
plt.boxplot(data, vert=True, patch_artist=True)
plt.title("Grapg of --- Box")
plt.xlabel("Type")
plt.ylabel("Value")
plt.show()

# %%
import plotly.express as px
import pandas as pd

# 示例数据
data = {
    'Date': ['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04', '2023-01-05'],
    'Sales': [150, 200, 300, 250, 400]
}

# 创建DataFrame
df = pd.DataFrame(data)

# 创建折线图
fig = px.line(df, x='Date', y='Sales', title='Daily Sales')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import plotly.express as px
#       2 import pandas as pd
#       4 # 示例数据
#
# File ~/.pyenv/versions/3.10.12/lib/python3.10/site-packages/plotly/express/__init__.py:9
#       7 pd = optional_imports.get_module("pandas")
#       8 if pd is None:
# ----> 9     raise ImportError(
#      10         """\
#      11 Plotly express requires pandas to be installed."""
#      12     )
#      14 from ._imshow import imshow
#      15 from ._chart_types import (  # noqa: F401
#      16     scatter,
#      17     scatter_3d,
#    (...)
#      50     density_mapbox,
#      51 )
#
# ImportError: Plotly express requires pandas to be installed.

# %%
print(1)
